# %%
import plotly

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
ls stab213_supplemental_files/
# Out:
# 2420.txt      2682.txt      Be67.txt      King2.txt
# 2477.txt      6940.txt      Gaia_cat.txt

# %%
ngc_2682 = pd.read_csv('stab213_supplemental_files/Gaia_cat.txt')

# %%
ngc_2682 = ngc_2682[ngc_2682['cluster']=="NGC_2682"].reset_index()

# %%
ngc_2682
# Out:
#       index           source_id       RAdeg      DEdeg      g_mag      g_rp  \
# 0     14170  604698306849407232  133.078791  11.397105  14.919369  0.543600
# 1     14171  604698345504195456  133.056635  11.393364  14.428984  0.512750
# 2     14172  604701025563850368  132.975697  11.391630  20.216871  1.138721
# 3     14173  604701128643010816  132.981408  11.402849  13.139835  0.446609
# 4     14174  604701163002747136  133.020764  11.383099  16.562843  0.896111
# ...     ...                 ...         ...        ...        ...       ...
# 1536  15706  598959822520052480  132.394796  11.788074  14.189812  0.481028
# 1537  15707  598959921303885952  132.414641  11.806690  18.442612  1.102053
# 1538  15708  598959955665887872  132.417570  11.807244  20.633884  1.188070
# 1539  15709  598960642858424576  132.365539  11.815901  19.527473  1.130579
# 1540  15710  598960956391419648  132.340389  11.834584  18.912483  1.124933
#
# ...

# %%
cat = ngc_2682

# %%
co = 0.7

# %%
qf_0 = cat[cat['qf']==0]
cand_0 = qf_0[(qf_0['P_F6']>=co) & (qf_0['P_F10']<co)]
field_0 = qf_0[(qf_0['P_F6']<co) | (qf_0['P_F10']>=co)]
qf_1 = cat[cat['qf']==1]
cand_1 = qf_1[(qf_1['P_F6']>=co) & (qf_1['P_F10']<co)]
field_1 = qf_1[(qf_1['P_F6']<co) | (qf_1['P_F10']>=co)]
cand = pd.concat([cand_0, cand_1], axis=0)

cat_M = cat[cat['class']=='M']
cat_C = cat[cat['class']=='C']

source_ids_1 = cand['source_id'].astype(str)
g_mag_1 = cand['g_mag'].round(4).astype(str)
g_rp_1 = cand['g_rp'].round(4).astype(str)
source_ids_2 = cat_C['source_id'].astype(str)
g_mag_2 = cat_C['g_mag'].round(4).astype(str)
g_rp_2 = cat_C['g_rp'].round(4).astype(str)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2,
                    horizontal_spacing=0.12,subplot_titles=("Comparision of P<sub>F6</sub> and P<sub>F10</sub>", "CMD of NGC 2682 (based on membership criteria)"))

fig.add_trace(go.Scatter(x = cand['P_F6'], y = cand['P_F10'], mode="markers", marker=dict(color='green',
                                                                                            symbol='circle-open',
                                                                            size=7), name='remove',
                         hoverinfo='text',hovertext = '<b>'+"Source ID: " + 
                         source_ids_1 +'</b>'+"<br>" + 'G[mag]: '+g_mag_1 + "<br>" + 'G - '+ 'G'+'<sub>'+'RP'+'</sub>'+ ': ' + g_rp_1, 
                         showlegend=False,
                        hoverlabel=dict(font=dict(family="Times New Roman"))), row=1, col=1)

fig.add_trace(go.Scatter(x = field_0['P_F6'], y = field_0['P_F10'], mode="markers", marker=dict(color='red',
                                                                                            symbol='circle-open',
                                                                            size=7), name='qf = 0',hoverinfo='skip'), row=1, col=1)


fig.add_trace(go.Scatter(x = field_1['P_F6'], y = field_1['P_F10'], mode="markers", marker=dict(color='black',
                                                                                            symbol='circle',
                                                                            size=4), name='qf = 1',hoverinfo='skip'), row=1, col=1)

fig.add_trace(go.Scatter(x=cat_M['g_rp'], y = cat_M['g_mag'], mode="markers", marker=dict(color='grey',size=2), name='Members', hoverinfo='skip'),row=1, col=2)
fig.add_trace(go.Scatter(x=cat_C['g_rp'], y = cat_C['g_mag'], mode="markers", marker=dict(color='green',
                                                                                          symbol="circle-open",size=7), name='Candidates',
                        hoverinfo='text',hovertext = '<b>'+"Source ID: " + 
                         source_ids_2 +'</b>'+"<br>" + 'G[mag]: ' + g_mag_2 + "<br>" + 'G - '+'G'+'<sub>'+'RP'+'</sub>'+ ': ' + g_rp_2, 
                       hoverlabel=dict(font=dict(family="Times New Roman")) ),row=1, col=2)

fig.add_hline(y=co, row=1, col=1)
fig.add_vline(x=co, row=1, col=1)

fig.update_xaxes(title_text=r"$\rm P_{F6}$", row=1, col=1)
fig.update_yaxes(title_text=r"$\rm P_{F10}$", row=1, col=1)
fig.update_xaxes(title_text=r"$\rm G-G_{RP}$", row=1, col=2)
fig.update_yaxes(title_text=r'$\rm G[mag]$', row=1, col=2)

fig.update_yaxes(autorange="reversed",row=1, col=2)

fig.update_layout(height=800, width=1400)
fig.update_traces(showlegend=False, selector=dict(type='scatter'),row=1, col=2)

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01,font = dict(family="Times New Roman", size=10)
))

fig.update_annotations(font_family="Times New Roman", font_size=20)

plotly.offline.plot(fig, filename='a_b.html',auto_open=False,include_mathjax='cdn')
fig.write_image('a_b_gaia.png')

# fig.update_layout(title=dict(text="Comparision of P_F6 and P_F10 and CMD of NGC 2682 (based on membership criteria)",xanchor= 'center',
#         yanchor= 'top',y=0.92, x=0.5),font=dict(
#         family="Times New Roman",
#         size=15)#,row=1,col=1)
fig.show()
# Out:
# <div>                            <div id="cadebab3-465f-4f2a-ad0b-35fd03d91563" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cadebab3-465f-4f2a-ad0b-35fd03d91563")) {                    Plotly.newPlot(                        "cadebab3-465f-4f2a-ad0b-35fd03d91563",                        [{"hoverinfo": "text", "hoverlabel": {"font": {"family": "Times New Roman"}}, "hovertext": ["<b>Source ID: 604701953276603520</b><br>G[mag]: 12.9622<br>G - G<sub>RP</sub>: 0.4555", "<b>Source ID: 604903090890049792</b><br>G[mag]: 19.8192<br>G - G<sub>RP</sub>: 1.1585", "<b>Source ID: 604903370063592192</b><br>G[mag]: 19.7835<br>G - G<sub>RP</sub>: 1.1722", "<b>Source ID: 604904778812856064</b><br>G[mag]: 15.1762<br>G - G<sub>RP</sub>: 0.6731", "<b>Source ID: 604
# ...

# %%
f_stars = cat[(cat['P_F6'] < co) & (cat['P_F8'] < co)]
m_c_stars = cat[(cat['P_F6'] >= co) | (cat['P_F8'] >= co)]

cat_wo_F = cat[cat['class']!='F']
cat_F = cat[cat['class']=='F']

peculiarity_1 = (m_c_stars['P_F6']-m_c_stars['P_F8']).round(3).astype(str)
gmag_1 = m_c_stars['g_mag'].round(4).astype(str)
grp_1 = m_c_stars['g_rp'].round(4).astype(str)
source_1 = m_c_stars['source_id'].astype(str)

peculiarity_2 = (cat_wo_F['P_F6']-cat_wo_F['P_F8']).round(3).astype(str)
gmag_2 = cat_wo_F['g_mag'].round(4).astype(str)
grp_2 = cat_wo_F['g_rp'].round(4).astype(str)
source_2 = cat_wo_F['source_id'].astype(str)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# fig = go.Figure()
fig = make_subplots(rows=1, cols=2,
                    horizontal_spacing=0.12,subplot_titles=("Comparision of P<sub>F6</sub> and P<sub>F8</sub>", "CMD of stars according to Peculiarity (P<sub>F6</sub> - P<sub>F8</sub>)")
                   )

fig.add_trace(go.Scatter(x=f_stars['P_F6'], y=f_stars['P_F8'], mode="markers", marker=dict(color='grey', size=2), 
#                          name=r"$\rm P_{F8} \; AND \; P_{F6} < co$",
                         name="P_F8 AND P_F6 < co",
                        hoverinfo='skip'), row=1, col=1)
fig.add_trace(go.Scatter(x=m_c_stars['P_F6'], y=m_c_stars['P_F8'], mode="markers", 
                         marker=dict(color=m_c_stars['P_F6']-m_c_stars['P_F8'],cmax=0.4, cmin=-0.4, 
                         colorbar=dict(
                             title=dict(
#                                  text = r"$\rm P_{F6} \; - \; P_{F8}$", 
#                                      text = "P_F6 - P_F8",
                                        text = "Peculiarity",
                                        side = "right", 
                                        font=dict(family = "Times New Roman",size=20)),
                             xpad=0, 
                             tickfont=dict(family="Times New Roman")), colorscale="Portland"), 
#                          name=r"$\rm P_{F8} \; OR \; P_{F6} > co$",
                         name="P_F8 AND P_F6 < co",
                         hoverinfo='text',hovertext = '<b>'+"Source ID: " + 
                         source_1 +'</b>'+"<br>" + 'G[mag]: ' + gmag_1 + "<br>" + 'G - '+'G'+'<sub>'+'RP'+'</sub>'+ ': ' + grp_1
                         + '<br>'+ 'Peculiarity: '+ peculiarity_1, 
                       hoverlabel=dict(font=dict(family="Times New Roman"))
                        ), row=1, col=1)

fig.add_trace(go.Scatter(x=cat_wo_F['g_rp'], y = cat_wo_F['g_mag'], mode="markers", 
                         marker=dict(color=cat_wo_F['P_F6']-cat_wo_F['P_F8'],cmax=0.4, cmin=-0.4, 
#                                      colorbar=dict(title=dict(text="P_F6 - P_F8",
#                                                              side="right", font=dict(family = "Times New Roman",size=17)), 
#                                                    tickfont=dict(family="Times New Roman"),
#                                                   len=0.55,y=0.25), 
                                     colorscale="Portland"
                                    ),
                                              hoverinfo='text',hovertext = '<b>'+"Source ID: " + 
                         source_2 +'</b>'+"<br>" + 'G[mag]: ' + gmag_2 + "<br>" + 'G - '+'G'+'<sub>'+'RP'+'</sub>'+ ': ' + grp_2
                         + '<br>'+ 'Peculiarity: '+ peculiarity_2, 
                       hoverlabel=dict(font=dict(family="Times New Roman"))
                        ),row=1, col=2)

fig.add_trace(go.Scatter(x=cat_F['g_rp'], y = cat_F['g_mag'], mode="markers", hoverinfo='skip',marker=dict(color='grey', size=2)),row=1, col=2)

fig.update_yaxes(autorange="reversed", row=1, col=2)

fig.add_hline(y=co, row=1, col=1)
fig.add_vline(x=co, row=1, col=1)

fig.update_xaxes(title_text=r"$\rm P_{F6}$", row=1, col=1)
fig.update_yaxes(title_text=r"$\rm P_{F8}$", row=1, col=1)
fig.update_xaxes(title_text=r"$\rm G-G_{RP}$", row=1, col=2)
fig.update_yaxes(title_text=r'$\rm G[mag]$', row=1, col=2)

fig.update_layout(height=800, width=1400)
fig.update_traces(showlegend=False, selector=dict(type='scatter'), row=1, col=2)
fig.update_traces(showlegend=False, selector=dict(type='scatter'), row=1, col=1)

fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01, font = dict(family="Times New Roman", size=12)
))

fig.update_annotations(font_family="Times New Roman", font_size=20)


plotly.offline.plot(fig, filename='c_d.html',auto_open=False,include_mathjax='cdn')
fig.write_image('c_d_gaia.png')

fig.show()
# Out:
# <div>                            <div id="5b0438f6-b41d-4a4c-986f-ab8a4232f662" class="plotly-graph-div" style="height:800px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b0438f6-b41d-4a4c-986f-ab8a4232f662")) {                    Plotly.newPlot(                        "5b0438f6-b41d-4a4c-986f-ab8a4232f662",                        [{"hoverinfo": "skip", "marker": {"color": "grey", "size": 2}, "mode": "markers", "name": "P_F8 AND P_F6 < co", "showlegend": false, "type": "scatter", "x": [0.4223950112569236, 0.30266793701957795, 0.2746940126179683, 0.05536080437211013, 0.06786514460639609, 0.2531624727943854, 0.5664359163127911, 0.08805614338709662, 0.2168248279878336, 0.3607650578135943, 0.2940583351604949, 0.04532903026801699, 0.18789941706705046, 0.04254051939053997, 0.6426554766715321, 0
# ...

# %%
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go

# fig = make_subplots(rows=2, cols=1,
#                     shared_xaxes=True,
#                     vertical_spacing=0.01)

# fig.add_trace(go.Scatter(x=cat_M['g_rp'], y = cat_M['g_mag'], mode="markers", marker=dict(color='grey',size=2), name='Members'),row=1, col=1)
# fig.add_trace(go.Scatter(x=cat_C['g_rp'], y = cat_C['g_mag'], mode="markers", marker=dict(color='green',symbol="triangle-up-open"), name='Candidates'),row=1, col=1)
# fig.add_trace(go.Scatter(x=cat_wo_F['g_rp'], y = cat_wo_F['g_mag'], mode="markers", 
#                          marker=dict(color=cat_wo_F['P_F6']-cat_wo_F['P_F8'],cmax=0.4, cmin=-0.4, 
#                                      colorbar=dict(title=dict(text="P_F6 - P_F8",
#                                                              side="right", font=dict(family = "Times New Roman",size=17)), 
#                                                    tickfont=dict(family="Times New Roman"),
#                                                   len=0.55,y=0.25), 
#                                      colorscale="Portland")),row=2, col=1)

# fig.add_trace(go.Scatter(x=cat_F['g_rp'], y = cat_F['g_mag'], mode="markers", marker=dict(color='grey', size=2)),row=2, col=1)
# fig.update_yaxes(autorange="reversed")
# fig.update_layout(height=800, width=500)

# fig.update_xaxes(title_text=r"$\rm G-G_{RP}$", row=2, col=1)
# fig.update_yaxes(title_text=r'$\rm G[mag]$', row=2, col=1)
# fig.update_yaxes(title_text=r'$\rm G[mag]$', row=1, col=1)

# fig.update_traces(showlegend=False, selector=dict(type='scatter'), row=2, col=1)
# fig.update_layout(legend=dict(
#     yanchor="top",
#     y=0.99,
#     xanchor="right",
#     x=0.99,font = dict(family="Times New Roman", size=12) ))

# fig.show()

# %%
# a,b,c and d
# source id
# g 
# g_rp
# peculiarity - c,d
# unicode for F

'''sideways matching, hover text, code cleaning, colorbar text tex render.'''
# Out:
# 'sideways matching, hover text, code cleaning, colorbar text tex render.'

# %%
# sideways matching - do we need it? Individual plots better
# hover on 3 different plots for 1.1 DONE 
# formatting :
#     fonts - mathtex on all tick labels - should be ok
#     colorbar - :(
#     legends - Solved if we are making individual plots
# simulatenous hover on 2 plots at once - IMPOSSIBLE
# plotly latex for labels on axes
# field stars problem - DONE

# also, c and d together make sense right? Same points, same axes. When u zoom one, the other also zooms and shows
# you the peculiarity

'''Future tasks:
    1. Customize hover text
    2. hover details
    3. 0.7 problem (0.6 in the paper but doesnt look like it)
    4. code cleaning'''
# Out:
# 'Future tasks:\n    1. Customize hover text\n    2. hover details\n    3. 0.7 problem (0.6 in the paper but doesnt look like it)\n    4. code cleaning'

# %%
# CODE DUMP

# fig.update_traces(hoverinfo=np.where(np.logical_and(ngc_2682[ngc_2682['qf']==0]['P_F6'] >= 0.7, ngc_2682[ngc_2682['qf']==0]['P_F10'] <= 0.7),'all','skip'), selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(ngc_2682['qf']==1,'skip', 'all'), selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(np.logical_and(ngc_2682[ngc_2682['qf']==1]['P_F6'] >= 0.7, ngc_2682[ngc_2682['qf']==1]['P_F10'] <= 0.7),'all','skip'), selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(np.logical_and(ngc_2682['P_F6'] >= 0.7, ngc_2682['P_F10'] <= 0.7),'all','skip'),
#                   selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(np.logical_and(qf_0['P_F6']>=0.7,qf_0['P_F10']<=0.7), 'all', 'skip'),
#                   selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(qf_1['P_F6']>=0.7, 'all', 'skip'),
#                   selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(np.logical_and(np.logical_and(np.logical_and(ngc_2682[ngc_2682['qf']==0]['P_F6'] >= 0.7, 
#                                                                    ngc_2682[ngc_2682['qf']==0]['P_F10'] <= 0.7), 
#                                                                     ngc_2682[ngc_2682['qf']==1]['P_F6'] >= 0.7), 
#                                                                    ngc_2682[ngc_2682['qf']==1]['P_F10'] <= 0.7),
#                   'all','skip'), selector=dict(type='scatter'), row=1, col=1)
# fig.update_traces(hoverinfo=np.where(np.logical_and.reduce((ngc_2682[ngc_2682['qf']==0]['P_F6'] >= 0.7,
#                                                             ngc_2682[ngc_2682['qf']==0]['P_F10'] <= 0.7,
#                                                             ngc_2682[ngc_2682['qf']==1]['P_F6'] >= 0.7,
#                                                             ngc_2682[ngc_2682['qf']==1]['P_F10'] <= 0.7)), 'all', 'skip'), selector=dict(type='scatter'), row=1, col=1)


# fig.add_trace(go.Scatter(x = ngc_2682['P_F6'], y = ngc_2682['P_F8'], mode="markers",
#                   marker=dict(
# #                       color=np.where(np.logical_and(ngc_2682['P_F6'] <= 0.7, ngc_2682['P_F8'] <= 0.7), 'grey', 'red'), 
#                               symbol=np.where(np.logical_and(ngc_2682['P_F6'] <= 0.7, ngc_2682['P_F8'] <= 0.7), 'cross', 'circle'),
#                             color= np.where(np.logical_and(ngc_2682['P_F6'] <= 0.7, ngc_2682['P_F8'] <= 0.7),'grey',ngc_2682['P_F6'] - ngc_2682['P_F8']), colorscale="Portland",
#                   cmax=0.4, cmin=-0.4, colorbar=dict(title='colorbar'))), row=2, col=1)

# %%
# plt.scatter(ngc_2682['P_F6'], ngc_2682['P_F10'])

# fig = px.scatter(ngc_2682, ngc_2682['P_F6'], ngc_2682['P_F10'],
#                  color=ngc_2682['qf'],
# #                  symbol=ngc_2682['qf'], 
#                  width=400, height=400)
# fig.add_hline(y=0.7)
# fig.add_vline(x=0.7)
# # fig.update_traces(marker_symbol=np.array(['cross','circle']), selector=dict(type='scatter'))
# fig.update_traces(x = ngc_2682['P_F6'], y = ngc_2682['P_F10'], mode="markers", showlegend=True,
#                   marker=dict(color = np.where(ngc_2682['qf']==0,'red','black'),symbol=np.where(ngc_2682['qf']==0,'cross','circle')))
# fig.show()

# a = ngc_2682[ngc_2682['class']!='F']

# fig = px.scatter(a, a['g_rp'], a['g_mag'],color=a['class'],symbol=a['class'], width=400, height=400)
# fig.update_yaxes(autorange="reversed")
# fig.show()

# fig = px.scatter(ngc_2682, ngc_2682['P_F6'], ngc_2682['P_F8'],
#                  color=ngc_2682['P_F6'] - ngc_2682['P_F8'],
#                  symbol=ngc_2682['P_F6']<0.6,
#                  width=400, height=400,
#                  color_continuous_scale=px.colors.diverging.Portland
#                 )
# fig.add_hline(y=0.7)
# fig.add_vline(x=0.7)
# fig.update_traces(marker_symbol=100, selector=dict(type='scatter'))
# fig.update_traces(showlegend=False, selector=dict(type='scatter'))
# fig.update_traces(x = ngc_2682['P_F6'], y = ngc_2682['P_F8'], mode="markers", marker=dict(color=(
#             (ngc_2682['P_F6'] <= 0.7) &
#             (ngc_2682['P_F8'] <= 0.7)
#         ).astype('int'),colorscale=[[0, 'red'], [1, 'green']], symbol='cross'))
# fig.update_traces(x = ngc_2682['P_F6'], y = ngc_2682['P_F8'], mode="markers", showlegend=True,
#                   marker=dict(color=np.where(np.logical_and(ngc_2682['P_F6'] <= 0.7, ngc_2682['P_F8'] <= 0.7), 'green', 'red'), symbol=np.where(np.logical_and(ngc_2682['P_F6'] <= 0.7, ngc_2682['P_F8'] <= 0.7), 'cross', 'circle')))
# fig.show()
